# %% [markdown]
# Praktikum 1

# %% [markdown]
# Langkah 1 - Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Langkah 2 - Pra Pengolahan Data

# %% [markdown]
# Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan, pembesaran (zoom), dan flip.

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory(r'D:\File untuk kuliah\Semester-5\Pembelajaran Mesin\Praktek\MachineLearning_Smst5_2025\JS14\Assets\dataset\dataset\training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# Langkah 2.2. Pra Pengolahan Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory(r'D:\File untuk kuliah\Semester-5\Pembelajaran Mesin\Praktek\MachineLearning_Smst5_2025\JS14\Assets\dataset\dataset\test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# Langkah 3 - Pembuatan Model CNN

# %% [markdown]
# Langkah 3.1.  - Inisiasi Model CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Langkah 3.2. - Pembuatan Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Langkah 3.3 - Pembuatan Layer Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Langkah 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Langkah 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# Langkah 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Langkah 3.8 - Compile Model CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Penggunaan loss function binary crossentropy dikarenakan kita hanya melakukan klasifikasi pada dua kelas, yaitu kucing dan anjing.

# %% [markdown]
# Langkah 4 - Fit CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 112s 443ms/step - accuracy: 0.5996 - loss: 0.6591 - val_accuracy: 0.6965 - val_loss: 0.5910
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 124ms/step - accuracy: 0.6901 - loss: 0.5849 - val_accuracy: 0.6790 - val_loss: 0.5940
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 123ms/step - accuracy: 0.7214 - loss: 0.5482 - val_accuracy: 0.7445 - val_loss: 0.5185
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.7377 - loss: 0.5275 - val_accuracy: 0.7555 - val_loss: 0.4996
# Epoch 5/25
# ...

# %% [markdown]
# Langkah 5 - Prediksi dengan 1 Citra

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img(r'D:\File untuk kuliah\Semester-5\Pembelajaran Mesin\Praktek\MachineLearning_Smst5_2025\JS14\Assets\dataset\dataset\single_prediction\cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
